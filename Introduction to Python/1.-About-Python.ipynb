# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np
print("ZA WORLD OVERHEAVEN!")




ϵ_values = np.random.randn(100)
plt.plot(ϵ_values)
plt.show()
# Out:
# ZA WORLD OVERHEAVEN!
# ZA WORLD OVERHEAVEN!
# 1
